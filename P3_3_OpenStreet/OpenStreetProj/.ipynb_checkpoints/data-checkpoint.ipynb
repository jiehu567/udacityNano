# %%
# import package
# Load packages and raw data file
import re
from collections import defaultdict
import json
import xml.etree.cElementTree as ET
import pprint
import numpy as np
import datetime as dt

osm_file = 'sf_sample.osm'

# %%
# type and number of nodes
dic = defaultdict(int)

for _, elem in ET.iterparse(osm_file):
    dic[elem.tag] +=1
print dic
# Out:
# defaultdict(int,
#             {'member': 5342,
#              'nd': 560829,
#              'node': 471488,
#              'osm': 1,
#              'relation': 566,
#              'tag': 174015,
#              'way': 55115})

# %%
def attach_node(temp_dic, node_name):
    for node in elem.iter(node_name):
            # add uid, version, changeset, user, id
            for key in ['uid', 'version', 'changeset', 'user', 'id']:    
                if node.attrib.has_key(key):
                    temp_dic[key] = node.attrib[key]

            # add position with latitude and longitude
            if node.attrib.has_key('lat') and node.attrib.has_key('lon'):
                temp_dic['position'] = {'lat': float(node.attrib['lat']),
                                        'lon': float(node.attrib['lon'])}

            # timestamp into year, month, day, hour, minute, second
            if node.attrib.has_key('timestamp'):
                time = dt.datetime.strptime(node.attrib['timestamp'], "%Y-%m-%dT%H:%M:%SZ")
                temp_dic['time'] = {'year': time.year,
                                    'month': time.month,
                                    'day': time.day,
                                    'hour': time.hour,
                                    'minute': time.minute}         # Here I think not necessary to extract second


            # attach data from key 'tag'
            for tag in node.iter('tag'):

                # attach tag value IN exit_to list
                exit_arr = []
                for key in ['exit_to','exit_to:left','exit_to:right']:
                    if tag.attrib['k'] == key:
                        exit_arr.append(tag.attrib['v'])

                if exit_arr != []:
                    temp_dic['exit_to'] = exit_arr

                # attach tag value NOT IN exit_to list
                if not tag.attrib['k'] in ['exit_to','exit_to:left','exit_to:right']:
                    temp_dic[tag.attrib['k']] = tag.attrib['v']

            temp_dic['node_type'] = node_name

# %%
# Process data

dic_sample = []

for _, elem in ET.iterparse(osm_file):

    temp_dic = {}
    
    
    # attach data from key 'member'
    for member in elem.iter('member'):
        for key in member.keys():
            if member.attrib[key] != "":
                temp_dic[key] = member.attrib[key]
            else:
                temp_dic[key] = None
    
    # attach data from key 'node'
    attach_node(temp_dic, 'node')
    
    # attach data from key 'relation', it's exactly the same as 'node'
    attach_node(temp_dic, 'relation')
    
    # attach data from key 'way', it's exactly the same as 'node'
    attach_node(temp_dic, 'way')
    
    if temp_dic != {}:
        dic_sample.append(temp_dic)

# %%
dic_sample
# Out:
# [{'changeset': '22950379',
#   'id': '281266',
#   'node_type': 'node',
#   'position': {'lat': 37.5601845, 'lon': -122.3025783},
#   'time': {'day': 15, 'hour': 18, 'minute': 55, 'month': 6, 'year': 2014},
#   'uid': '1660455',
#   'user': 'juergenb22',
#   'version': '6'},
#  {'changeset': '4472283',
#   'id': '26117856',
#   'node_type': 'node',
#   'position': {'lat': 37.5860936, 'lon': -122.3313774},
#   'time': {'day': 19, 'hour': 20, 'minute': 46, 'month': 4, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '15'},
#  {'changeset': '36847187',
#   'id': '26795963',
#   'node_type': 'node',
#   'position': {'lat': 37.6097145, 'lon': -122.3916753},
#   'time': {'day': 27, 'hour': 22, 'minute': 33, 'month': 1, 'year': 2016},
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '19'},
#  {'changeset': '10936318',
#   'id': '29891422',
#   'node_type': 'node',
#   'position': {'lat': 37.6897725, 'lon': -122.1017753},
#   'time': {'day': 10, 'hour': 20, 'minute': 18, 'month': 3, 'year': 2012},
#   'uid': '482916',
#   'user': 'bill42',
#   'version': '18'},
#  {'changeset': '36866799',
#   'exit_to': ['Hesperian Boulevard'],
#   'highway': 'motorway_junction',
#   'id': '29891439',
#   'node_type': 'node',
#   'position': {'lat': 37.6378577, 'lon': -122.0980391},
#   'ref': '25B',
#   'source': 'survey;http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/92.pdf',
#   'time': {'day': 28, 'hour': 22, 'minute': 8, 'month': 1, 'year': 2016},
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '6'},
#  {'changeset': '5595644',
#   'id': '29891966',
#   'node_type': 'node',
#   'position': {'lat': 37.6358054, 'lon': -122.4035252},
#   'time': {'day': 26, 'hour': 4, 'minute': 41, 'month': 8, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'changeset': '4943615',
#   'id': '29891976',
#   'node_type': 'node',
#   'position': {'lat': 37.7095454, 'lon': -122.395135},
#   'time': {'day': 9, 'hour': 9, 'minute': 12, 'month': 6, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '74256',
#   'id': '29892648',
#   'node_type': 'node',
#   'position': {'lat': 37.8507074, 'lon': -122.4900824},
#   'time': {'day': 2, 'hour': 7, 'minute': 39, 'month': 4, 'year': 2009},
#   'uid': '24452',
#   'user': 'Speight',
#   'version': '7'},
#  {'changeset': '74256',
#   'id': '29892658',
#   'node_type': 'node',
#   'position': {'lat': 37.8706206, 'lon': -122.5072542},
#   'time': {'day': 2, 'hour': 7, 'minute': 39, 'month': 4, 'year': 2009},
#   'uid': '24452',
#   'user': 'Speight',
#   'version': '8'},
#  {'changeset': '1705653',
#   'id': '29892668',
#   'node_type': 'node',
#   'position': {'lat': 37.9442039, 'lon': -122.5150486},
#   'time': {'day': 1, 'hour': 23, 'minute': 41, 'month': 7, 'year': 2009},
#   'uid': '25510',
#   'user': 'Apo42',
#   'version': '3'},
#  {'changeset': '3949010',
#   'id': '30029483',
#   'node_type': 'node',
#   'position': {'lat': 37.7019213, 'lon': -122.0341958},
#   'time': {'day': 23, 'hour': 0, 'minute': 44, 'month': 2, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '13'},
#  {'changeset': '4655972',
#   'id': '30029507',
#   'node_type': 'node',
#   'position': {'lat': 37.6885698, 'lon': -122.1337471},
#   'time': {'day': 10, 'hour': 5, 'minute': 21, 'month': 5, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'changeset': '4472283',
#   'id': '30033661',
#   'node_type': 'node',
#   'position': {'lat': 37.5853688, 'lon': -122.3299773},
#   'time': {'day': 19, 'hour': 20, 'minute': 46, 'month': 4, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '15'},
#  {'changeset': '6887687',
#   'id': '30033681',
#   'node_type': 'node',
#   'position': {'lat': 37.6120362, 'lon': -122.3946931},
#   'time': {'day': 6, 'hour': 22, 'minute': 38, 'month': 1, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '12'},
#  {'changeset': '15687289',
#   'id': '30033697',
#   'node_type': 'node',
#   'position': {'lat': 37.6763377, 'lon': -122.3885599},
#   'time': {'day': 11, 'hour': 9, 'minute': 26, 'month': 4, 'year': 2013},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '74256',
#   'id': '30033746',
#   'node_type': 'node',
#   'position': {'lat': 37.8551107, 'lon': -122.4938119},
#   'time': {'day': 2, 'hour': 7, 'minute': 39, 'month': 4, 'year': 2009},
#   'uid': '24452',
#   'user': 'Speight',
#   'version': '7'},
#  {'changeset': '74256',
#   'id': '30033756',
#   'node_type': 'node',
#   'position': {'lat': 37.9107857, 'lon': -122.5130686},
#   'time': {'day': 2, 'hour': 7, 'minute': 37, 'month': 4, 'year': 2009},
#   'uid': '24452',
#   'user': 'Speight',
#   'version': '4'},
#  {'changeset': '4149448',
#   'id': '30362145',
#   'node_type': 'node',
#   'position': {'lat': 37.8155917, 'lon': -122.2987091},
#   'time': {'day': 17, 'hour': 5, 'minute': 43, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '4149448',
#   'id': '30362156',
#   'node_type': 'node',
#   'position': {'lat': 37.8217935, 'lon': -122.2982612},
#   'time': {'day': 17, 'hour': 5, 'minute': 45, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '4169844',
#   'id': '30362585',
#   'node_type': 'node',
#   'position': {'lat': 37.8324766, 'lon': -122.2935128},
#   'time': {'day': 19, 'hour': 13, 'minute': 15, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '4150170',
#   'id': '30362900',
#   'node_type': 'node',
#   'position': {'lat': 37.8301807, 'lon': -122.2940306},
#   'time': {'day': 17, 'hour': 8, 'minute': 52, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '4149371',
#   'id': '30363883',
#   'node_type': 'node',
#   'position': {'lat': 37.8255792, 'lon': -122.3067157},
#   'time': {'day': 17, 'hour': 5, 'minute': 4, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'changeset': '4147608',
#   'id': '30364094',
#   'node_type': 'node',
#   'position': {'lat': 37.8253891, 'lon': -122.3087563},
#   'time': {'day': 16, 'hour': 22, 'minute': 25, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '4147608',
#   'id': '30364104',
#   'node_type': 'node',
#   'position': {'lat': 37.8239525, 'lon': -122.308555},
#   'time': {'day': 16, 'hour': 22, 'minute': 25, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'changeset': '11442054',
#   'id': '30364616',
#   'node_type': 'node',
#   'position': {'lat': 37.8374909, 'lon': -122.2962734},
#   'time': {'day': 28, 'hour': 15, 'minute': 43, 'month': 4, 'year': 2012},
#   'uid': '178186',
#   'user': 'mdk',
#   'version': '10'},
#  {'changeset': '4149371',
#   'id': '30365522',
#   'node_type': 'node',
#   'position': {'lat': 37.8244224, 'lon': -122.3060102},
#   'time': {'day': 17, 'hour': 5, 'minute': 14, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '2'},
#  {'changeset': '4149371',
#   'id': '30365940',
#   'node_type': 'node',
#   'position': {'lat': 37.8249584, 'lon': -122.3060961},
#   'time': {'day': 17, 'hour': 5, 'minute': 8, 'month': 3, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'changeset': '16981620',
#   'id': '30366151',
#   'node_type': 'node',
#   'position': {'lat': 37.8271742, 'lon': -122.2844094},
#   'time': {'day': 17, 'hour': 2, 'minute': 14, 'month': 7, 'year': 2013},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '13'},
#  {'changeset': '5737148',
#   'id': '30372595',
#   'node_type': 'node',
#   'position': {'lat': 37.8110319, 'lon': -122.2748414},
#   'time': {'day': 9, 'hour': 22, 'minute': 39, 'month': 9, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '16'},
#  {'changeset': '36824999',
#   'id': '30373971',
#   'node_type': 'node',
#   'position': {'lat': 37.8084449, 'lon': -122.2762512},
#   'time': {'day': 26, 'hour': 20, 'minute': 39, 'month': 1, 'year': 2016},
#   'uid': '2226712',
#   'user': 'dannykath',
#   'version': '5'},
#  {'changeset': '7389774',
#   'id': '30374151',
#   'node_type': 'node',
#   'position': {'lat': 37.8003122, 'lon': -122.2798442},
#   'time': {'day': 25, 'hour': 12, 'minute': 9, 'month': 2, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '24'},
#  {'changeset': '36820062',
#   'id': '30374192',
#   'node_type': 'node',
#   'position': {'lat': 37.8056613, 'lon': -122.3044575},
#   'time': {'day': 26, 'hour': 16, 'minute': 14, 'month': 1, 'year': 2016},
#   'uid': '2226712',
#   'user': 'dannykath',
#   'version': '5'},
#  {'changeset': '36822295',
#   'id': '30374272',
#   'node_type': 'node',
#   'position': {'lat': 37.8016112, 'lon': -122.2821429},
#   'time': {'day': 26, 'hour': 18, 'minute': 18, 'month': 1, 'year': 2016},
#   'uid': '2226712',
#   'user': 'dannykath',
#   'version': '10'},
#  {'changeset': '7186612',
#   'id': '30677582',
#   'node_type': 'node',
#   'position': {'lat': 37.7784646, 'lon': -122.3907111},
#   'time': {'day': 4, 'hour': 20, 'minute': 40, 'month': 2, 'year': 2011},
#   'uid': '4902',
#   'user': 'mbuege',
#   'version': '5'},
#  {'changeset': '34703873',
#   'id': '30677712',
#   'node_type': 'node',
#   'position': {'lat': 37.7666173, 'lon': -122.4531815},
#   'time': {'day': 18, 'hour': 1, 'minute': 52, 'month': 10, 'year': 2015},
#   'uid': '371121',
#   'user': 'AndrewSnow',
#   'version': '13'},
#  {'changeset': '8197173',
#   'id': '30677908',
#   'node_type': 'node',
#   'position': {'lat': 37.4683412, 'lon': -122.2920685},
#   'time': {'day': 20, 'hour': 10, 'minute': 1, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '45'},
#  {'changeset': '8197393',
#   'id': '30677922',
#   'node_type': 'node',
#   'position': {'lat': 37.4915206, 'lon': -122.299917},
#   'time': {'day': 20, 'hour': 10, 'minute': 32, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '45'},
#  {'changeset': '8196706',
#   'id': '30677934',
#   'node_type': 'node',
#   'position': {'lat': 37.4997863, 'lon': -122.3182333},
#   'time': {'day': 20, 'hour': 9, 'minute': 6, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '35'},
#  {'changeset': '5589997',
#   'id': '30677945',
#   'node_type': 'node',
#   'position': {'lat': 37.5039871, 'lon': -122.3333519},
#   'time': {'day': 25, 'hour': 13, 'minute': 51, 'month': 8, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '38'},
#  {'changeset': '8197393',
#   'id': '31053099',
#   'node_type': 'node',
#   'position': {'lat': 37.4858399, 'lon': -122.298555},
#   'time': {'day': 20, 'hour': 10, 'minute': 32, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '39'},
#  {'changeset': '8196968',
#   'id': '31053112',
#   'node_type': 'node',
#   'position': {'lat': 37.457109, 'lon': -122.2887997},
#   'time': {'day': 20, 'hour': 9, 'minute': 38, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '43'},
#  {'changeset': '5589997',
#   'id': '31053253',
#   'node_type': 'node',
#   'position': {'lat': 37.5002639, 'lon': -122.3226735},
#   'time': {'day': 25, 'hour': 13, 'minute': 53, 'month': 8, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '31'},
#  {'changeset': '35871857',
#   'id': '31354485',
#   'node_type': 'node',
#   'position': {'lat': 37.5099346, 'lon': -122.3330306},
#   'time': {'day': 10, 'hour': 19, 'minute': 14, 'month': 12, 'year': 2015},
#   'uid': '2377377',
#   'user': 'abel801',
#   'version': '37'},
#  {'changeset': '32548702',
#   'exit_to': ['CA 92 E;San Meteo Hayward'],
#   'highway': 'motorway_junction',
#   'id': '31416669',
#   'node_type': 'node',
#   'noref': 'yes',
#   'position': {'lat': 37.5038502, 'lon': -122.3327818},
#   'time': {'day': 10, 'hour': 16, 'minute': 56, 'month': 7, 'year': 2015},
#   'uid': '2655992',
#   'user': 'steverumizen',
#   'version': '20'},
#  {'changeset': '1658707',
#   'id': '31652107',
#   'node_type': 'node',
#   'position': {'lat': 37.8253011, 'lon': -122.3119672},
#   'time': {'day': 28, 'hour': 6, 'minute': 41, 'month': 6, 'year': 2009},
#   'uid': '24452',
#   'user': 'Speight',
#   'version': '2'},
#  {'changeset': '12291161',
#   'id': '31788554',
#   'node_type': 'node',
#   'position': {'lat': 37.8104398, 'lon': -122.424342},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '7'},
#  {'changeset': '12290631',
#   'id': '31789189',
#   'node_type': 'node',
#   'position': {'lat': 37.8368874, 'lon': -122.3069237},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31789997',
#   'node_type': 'node',
#   'position': {'lat': 37.5452822, 'lon': -122.2798917},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292969',
#   'id': '31790288',
#   'node_type': 'node',
#   'position': {'lat': 37.7103521, 'lon': -122.3794465},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12292607',
#   'id': '31790645',
#   'node_type': 'node',
#   'position': {'lat': 37.590347, 'lon': -122.3246205},
#   'time': {'day': 18, 'hour': 18, 'minute': 30, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '17255678',
#   'id': '31791108',
#   'node_type': 'node',
#   'position': {'lat': 37.8263329, 'lon': -122.3030503},
#   'time': {'day': 7, 'hour': 15, 'minute': 56, 'month': 8, 'year': 2013},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '12297016',
#   'id': '31791797',
#   'node_type': 'node',
#   'position': {'lat': 37.8895629, 'lon': -122.5016677},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12297016',
#   'id': '31792203',
#   'node_type': 'node',
#   'position': {'lat': 37.8818928, 'lon': -122.5149288},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '42369141',
#   'id': '31792960',
#   'node_type': 'node',
#   'position': {'lat': 37.8065725, 'lon': -122.4528278},
#   'time': {'day': 23, 'hour': 9, 'minute': 49, 'month': 9, 'year': 2016},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '8'},
#  {'changeset': '12290510',
#   'id': '31793429',
#   'node_type': 'node',
#   'position': {'lat': 37.9186783, 'lon': -122.3651669},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12297016',
#   'id': '31794164',
#   'node_type': 'node',
#   'position': {'lat': 37.8862634, 'lon': -122.5147642},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290631',
#   'id': '31794510',
#   'node_type': 'node',
#   'position': {'lat': 37.7952363, 'lon': -122.2879182},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '14617259',
#   'id': '31795041',
#   'node_type': 'node',
#   'position': {'lat': 37.5512177, 'lon': -122.1216015},
#   'time': {'day': 12, 'hour': 0, 'minute': 23, 'month': 1, 'year': 2013},
#   'uid': '635896',
#   'user': 'bigwebguy',
#   'version': '4'},
#  {'changeset': '16612448',
#   'id': '31795646',
#   'node_type': 'node',
#   'position': {'lat': 37.8003357, 'lon': -122.3301039},
#   'time': {'day': 19, 'hour': 4, 'minute': 53, 'month': 6, 'year': 2013},
#   'uid': '190493',
#   'user': 'vonvonvon',
#   'version': '5'},
#  {'changeset': '14617259',
#   'id': '31795902',
#   'node_type': 'node',
#   'position': {'lat': 37.561539, 'lon': -122.1089229},
#   'time': {'day': 12, 'hour': 0, 'minute': 23, 'month': 1, 'year': 2013},
#   'uid': '635896',
#   'user': 'bigwebguy',
#   'version': '4'},
#  {'changeset': '12290631',
#   'id': '31796101',
#   'node_type': 'node',
#   'position': {'lat': 37.7782963, 'lon': -122.2983614},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291003',
#   'id': '31796193',
#   'node_type': 'node',
#   'position': {'lat': 37.8872251, 'lon': -122.4761826},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291003',
#   'id': '31796447',
#   'node_type': 'node',
#   'position': {'lat': 37.9464027, 'lon': -122.4850642},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31796558',
#   'node_type': 'node',
#   'position': {'lat': 37.7530649, 'lon': -122.3816528},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31796889',
#   'node_type': 'node',
#   'position': {'lat': 37.5703783, 'lon': -122.2943199},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '27778077',
#   'id': '31797286',
#   'node_type': 'node',
#   'position': {'lat': 37.819813, 'lon': -122.3606307},
#   'time': {'day': 29, 'hour': 14, 'minute': 41, 'month': 12, 'year': 2014},
#   'uid': '152074',
#   'user': 'beweta',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31797711',
#   'node_type': 'node',
#   'position': {'lat': 37.5462077, 'lon': -122.2523572},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290510',
#   'id': '31798057',
#   'node_type': 'node',
#   'position': {'lat': 37.9095246, 'lon': -122.3362621},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290799',
#   'id': '31798557',
#   'node_type': 'node',
#   'position': {'lat': 37.8122991, 'lon': -122.3676198},
#   'time': {'day': 18, 'hour': 17, 'minute': 36, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12291412',
#   'id': '31799222',
#   'node_type': 'node',
#   'position': {'lat': 37.8558042, 'lon': -122.4413666},
#   'time': {'day': 18, 'hour': 18, 'minute': 1, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290025',
#   'id': '31799990',
#   'node_type': 'node',
#   'position': {'lat': 37.6479066, 'lon': -122.1549312},
#   'time': {'day': 18, 'hour': 17, 'minute': 8, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290510',
#   'id': '31800185',
#   'node_type': 'node',
#   'position': {'lat': 37.9055144, 'lon': -122.3698541},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '14617259',
#   'id': '31800390',
#   'node_type': 'node',
#   'position': {'lat': 37.5315881, 'lon': -122.0960023},
#   'time': {'day': 12, 'hour': 0, 'minute': 23, 'month': 1, 'year': 2013},
#   'uid': '635896',
#   'user': 'bigwebguy',
#   'version': '5'},
#  {'changeset': '13138664',
#   'id': '31800965',
#   'node_type': 'node',
#   'position': {'lat': 37.7605149, 'lon': -122.2232009},
#   'time': {'day': 17, 'hour': 6, 'minute': 2, 'month': 9, 'year': 2012},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'changeset': '12297016',
#   'id': '31801863',
#   'node_type': 'node',
#   'position': {'lat': 37.8837335, 'lon': -122.506378},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31802250',
#   'node_type': 'node',
#   'position': {'lat': 37.5527704, 'lon': -122.2836405},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12289485',
#   'id': '31802949',
#   'node_type': 'node',
#   'position': {'lat': 37.7693365, 'lon': -122.2325702},
#   'time': {'day': 18, 'hour': 16, 'minute': 48, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12289485',
#   'id': '31803797',
#   'node_type': 'node',
#   'position': {'lat': 37.7756937, 'lon': -122.2411748},
#   'time': {'day': 18, 'hour': 16, 'minute': 48, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290025',
#   'id': '31805258',
#   'node_type': 'node',
#   'position': {'lat': 37.6870498, 'lon': -122.1810139},
#   'time': {'day': 18, 'hour': 17, 'minute': 8, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290631',
#   'id': '31805921',
#   'node_type': 'node',
#   'position': {'lat': 37.836907, 'lon': -122.3002882},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '14617259',
#   'id': '31806514',
#   'node_type': 'node',
#   'position': {'lat': 37.5247714, 'lon': -122.1003025},
#   'time': {'day': 12, 'hour': 0, 'minute': 23, 'month': 1, 'year': 2013},
#   'uid': '635896',
#   'user': 'bigwebguy',
#   'version': '6'},
#  {'changeset': '17480668',
#   'id': '31807103',
#   'node_type': 'node',
#   'position': {'lat': 37.5912586, 'lon': -122.3467277},
#   'time': {'day': 24, 'hour': 8, 'minute': 12, 'month': 8, 'year': 2013},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '34148001',
#   'id': '31808304',
#   'node_type': 'node',
#   'position': {'lat': 37.8912995, 'lon': -122.5178831},
#   'time': {'day': 20, 'hour': 19, 'minute': 38, 'month': 9, 'year': 2015},
#   'uid': '153669',
#   'user': 'dchiles',
#   'version': '5'},
#  {'changeset': '20861979',
#   'id': '31809284',
#   'node_type': 'node',
#   'position': {'lat': 37.7905977, 'lon': -122.3019878},
#   'time': {'day': 2, 'hour': 10, 'minute': 59, 'month': 3, 'year': 2014},
#   'uid': '902727',
#   'user': 'javbw',
#   'version': '5'},
#  {'changeset': '16507049',
#   'id': '31810150',
#   'node_type': 'node',
#   'position': {'lat': 37.8066097, 'lon': -122.4503516},
#   'time': {'day': 11, 'hour': 8, 'minute': 34, 'month': 6, 'year': 2013},
#   'uid': '93788',
#   'user': 'coleman',
#   'version': '7'},
#  {'changeset': '16613122',
#   'id': '31810444',
#   'node_type': 'node',
#   'position': {'lat': 37.6982998, 'lon': -122.1894484},
#   'time': {'day': 19, 'hour': 6, 'minute': 46, 'month': 6, 'year': 2013},
#   'uid': '190493',
#   'user': 'vonvonvon',
#   'version': '6'},
#  {'changeset': '12291003',
#   'id': '31811001',
#   'node_type': 'node',
#   'position': {'lat': 37.9160366, 'lon': -122.4747254},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31811780',
#   'node_type': 'node',
#   'position': {'lat': 37.8539219, 'lon': -122.4355464},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290510',
#   'id': '31812051',
#   'node_type': 'node',
#   'position': {'lat': 37.8751196, 'lon': -122.3179748},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290631',
#   'id': '31812588',
#   'node_type': 'node',
#   'position': {'lat': 37.7680947, 'lon': -122.3038753},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12297016',
#   'id': '31813039',
#   'node_type': 'node',
#   'position': {'lat': 37.8828888, 'lon': -122.5186042},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '26355941',
#   'id': '31813546',
#   'node_type': 'node',
#   'position': {'lat': 37.6717439, 'lon': -122.3821956},
#   'time': {'day': 27, 'hour': 5, 'minute': 23, 'month': 10, 'year': 2014},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '34237134',
#   'id': '31814154',
#   'node_type': 'node',
#   'position': {'lat': 37.790349, 'lon': -122.2757339},
#   'time': {'day': 25, 'hour': 1, 'minute': 32, 'month': 9, 'year': 2015},
#   'uid': '3260615',
#   'user': 'SFBay1234',
#   'version': '8'},
#  {'changeset': '12290799',
#   'id': '31815027',
#   'node_type': 'node',
#   'position': {'lat': 37.8204416, 'lon': -122.3290904},
#   'time': {'day': 18, 'hour': 17, 'minute': 36, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290072',
#   'id': '31815819',
#   'node_type': 'node',
#   'position': {'lat': 37.7480932, 'lon': -122.2355861},
#   'time': {'day': 18, 'hour': 17, 'minute': 10, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290233',
#   'id': '31816046',
#   'node_type': 'node',
#   'position': {'lat': 37.5111361, 'lon': -122.2472611},
#   'time': {'day': 18, 'hour': 17, 'minute': 15, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290631',
#   'id': '31816343',
#   'node_type': 'node',
#   'position': {'lat': 37.766807, 'lon': -122.287352},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12291003',
#   'id': '31816800',
#   'node_type': 'node',
#   'position': {'lat': 37.8938159, 'lon': -122.4927308},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291412',
#   'id': '31817030',
#   'node_type': 'node',
#   'position': {'lat': 37.8680374, 'lon': -122.4383026},
#   'time': {'day': 18, 'hour': 18, 'minute': 2, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12291887',
#   'id': '31817345',
#   'node_type': 'node',
#   'position': {'lat': 37.6626358, 'lon': -122.3745972},
#   'time': {'day': 18, 'hour': 18, 'minute': 16, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '34236489',
#   'id': '31817557',
#   'node_type': 'node',
#   'position': {'lat': 37.786139, 'lon': -122.2704272},
#   'time': {'day': 24, 'hour': 23, 'minute': 52, 'month': 9, 'year': 2015},
#   'uid': '3260615',
#   'user': 'SFBay1234',
#   'version': '7'},
#  {'changeset': '34236756',
#   'id': '31818243',
#   'node_type': 'node',
#   'position': {'lat': 37.7918058, 'lon': -122.2729253},
#   'time': {'day': 25, 'hour': 0, 'minute': 31, 'month': 9, 'year': 2015},
#   'uid': '3260615',
#   'user': 'SFBay1234',
#   'version': '5'},
#  {'changeset': '12291433',
#   'id': '31818413',
#   'node_type': 'node',
#   'position': {'lat': 37.8725797, 'lon': -122.4561987},
#   'time': {'day': 18, 'hour': 18, 'minute': 2, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12291887',
#   'id': '31819100',
#   'node_type': 'node',
#   'position': {'lat': 37.7213463, 'lon': -122.3602419},
#   'time': {'day': 18, 'hour': 18, 'minute': 16, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290912',
#   'id': '31819315',
#   'node_type': 'node',
#   'position': {'lat': 37.9124328, 'lon': -122.3883118},
#   'time': {'day': 18, 'hour': 17, 'minute': 39, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290510',
#   'id': '31819415',
#   'node_type': 'node',
#   'position': {'lat': 37.9003834, 'lon': -122.3576124},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '16131163',
#   'id': '31819710',
#   'node_type': 'node',
#   'position': {'lat': 37.88817, 'lon': -122.323576},
#   'source': 'PGS',
#   'time': {'day': 14, 'hour': 20, 'minute': 51, 'month': 5, 'year': 2013},
#   'uid': '116769',
#   'user': 'probabble',
#   'version': '3'},
#  {'changeset': '12290631',
#   'id': '31820005',
#   'node_type': 'node',
#   'position': {'lat': 37.7944631, 'lon': -122.2933341},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291860',
#   'id': '31820319',
#   'node_type': 'node',
#   'position': {'lat': 37.7363309, 'lon': -122.2567262},
#   'time': {'day': 18, 'hour': 18, 'minute': 15, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '29206031',
#   'id': '31820420',
#   'node_type': 'node',
#   'position': {'lat': 37.8059463, 'lon': -122.4564339},
#   'time': {'day': 2, 'hour': 19, 'minute': 3, 'month': 3, 'year': 2015},
#   'uid': '2441939',
#   'user': 'thevirginian',
#   'version': '9'},
#  {'changeset': '12292969',
#   'id': '31820580',
#   'node_type': 'node',
#   'position': {'lat': 37.6672989, 'lon': -122.3857379},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292969',
#   'id': '31820728',
#   'node_type': 'node',
#   'position': {'lat': 37.6548941, 'lon': -122.3765919},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291412',
#   'id': '31820860',
#   'node_type': 'node',
#   'position': {'lat': 37.8598738, 'lon': -122.4438571},
#   'time': {'day': 18, 'hour': 18, 'minute': 2, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12291161',
#   'id': '31821050',
#   'node_type': 'node',
#   'position': {'lat': 37.8316029, 'lon': -122.3750468},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12297016',
#   'id': '31821304',
#   'node_type': 'node',
#   'position': {'lat': 37.891494, 'lon': -122.5218591},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '26355941',
#   'id': '31821524',
#   'node_type': 'node',
#   'position': {'lat': 37.6717539, 'lon': -122.3812187},
#   'time': {'day': 27, 'hour': 5, 'minute': 23, 'month': 10, 'year': 2014},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '12291887',
#   'id': '31821652',
#   'node_type': 'node',
#   'position': {'lat': 37.7177586, 'lon': -122.3679841},
#   'time': {'day': 18, 'hour': 18, 'minute': 16, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '7'},
#  {'changeset': '12290631',
#   'id': '31821735',
#   'node_type': 'node',
#   'position': {'lat': 37.8221418, 'lon': -122.3120332},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291003',
#   'id': '31821948',
#   'node_type': 'node',
#   'position': {'lat': 37.8830807, 'lon': -122.4986265},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31822031',
#   'node_type': 'node',
#   'position': {'lat': 37.811456, 'lon': -122.4188098},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12291161',
#   'id': '31822311',
#   'node_type': 'node',
#   'position': {'lat': 37.7892713, 'lon': -122.3850957},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12297372',
#   'id': '31822732',
#   'node_type': 'node',
#   'position': {'lat': 37.781371, 'lon': -122.5138059},
#   'time': {'day': 18, 'hour': 20, 'minute': 32, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12291003',
#   'id': '31822938',
#   'node_type': 'node',
#   'position': {'lat': 37.9383458, 'lon': -122.4932314},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12297016',
#   'id': '31823110',
#   'node_type': 'node',
#   'position': {'lat': 37.9440592, 'lon': -122.5065608},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '7'},
#  {'changeset': '12290631',
#   'id': '31823360',
#   'node_type': 'node',
#   'position': {'lat': 37.8367799, 'lon': -122.3046792},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31823979',
#   'node_type': 'node',
#   'position': {'lat': 37.5637743, 'lon': -122.2883334},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12291161',
#   'id': '31824393',
#   'node_type': 'node',
#   'position': {'lat': 37.8707703, 'lon': -122.4277287},
#   'time': {'day': 18, 'hour': 17, 'minute': 51, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '19241117',
#   'id': '31824490',
#   'node_type': 'node',
#   'position': {'lat': 37.731639, 'lon': -122.3656832},
#   'time': {'day': 2, 'hour': 21, 'minute': 8, 'month': 12, 'year': 2013},
#   'uid': '27454',
#   'user': 'Popolon',
#   'version': '5'},
#  {'changeset': '12291887',
#   'id': '31824551',
#   'node_type': 'node',
#   'position': {'lat': 37.7191288, 'lon': -122.3742497},
#   'time': {'day': 18, 'hour': 18, 'minute': 16, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12290631',
#   'id': '31824631',
#   'node_type': 'node',
#   'position': {'lat': 37.7933765, 'lon': -122.2960483},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '17255678',
#   'id': '31824776',
#   'node_type': 'node',
#   'position': {'lat': 37.8330651, 'lon': -122.2965593},
#   'time': {'day': 7, 'hour': 15, 'minute': 56, 'month': 8, 'year': 2013},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '4'},
#  {'changeset': '12292607',
#   'id': '31824888',
#   'node_type': 'node',
#   'position': {'lat': 37.5920579, 'lon': -122.3454504},
#   'time': {'day': 18, 'hour': 18, 'minute': 30, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290072',
#   'id': '31825074',
#   'node_type': 'node',
#   'position': {'lat': 37.7019284, 'lon': -122.2111729},
#   'time': {'day': 18, 'hour': 17, 'minute': 9, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12292607',
#   'id': '31825490',
#   'node_type': 'node',
#   'position': {'lat': 37.5920439, 'lon': -122.3429172},
#   'time': {'day': 18, 'hour': 18, 'minute': 30, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31825731',
#   'node_type': 'node',
#   'position': {'lat': 37.5503533, 'lon': -122.2858713},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290072',
#   'id': '31826115',
#   'node_type': 'node',
#   'position': {'lat': 37.7460742, 'lon': -122.2224135},
#   'time': {'day': 18, 'hour': 17, 'minute': 10, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12297016',
#   'id': '31826273',
#   'node_type': 'node',
#   'position': {'lat': 37.891268, 'lon': -122.5202989},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290072',
#   'id': '31826429',
#   'node_type': 'node',
#   'position': {'lat': 37.6955389, 'lon': -122.1879917},
#   'time': {'day': 18, 'hour': 17, 'minute': 9, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12292969',
#   'id': '31826495',
#   'node_type': 'node',
#   'position': {'lat': 37.6655098, 'lon': -122.3882527},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291412',
#   'id': '31826562',
#   'node_type': 'node',
#   'position': {'lat': 37.8321339, 'lon': -122.4727152},
#   'time': {'day': 18, 'hour': 18, 'minute': 1, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '15865774',
#   'id': '31826635',
#   'node_type': 'node',
#   'position': {'lat': 37.8901994, 'lon': -122.3230005},
#   'source': 'PGS',
#   'time': {'day': 25, 'hour': 21, 'minute': 14, 'month': 4, 'year': 2013},
#   'uid': '153669',
#   'user': 'dchiles',
#   'version': '2'},
#  {'changeset': '12292607',
#   'id': '31826748',
#   'node_type': 'node',
#   'position': {'lat': 37.5903678, 'lon': -122.3173273},
#   'time': {'day': 18, 'hour': 18, 'minute': 30, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12292084',
#   'id': '31826887',
#   'node_type': 'node',
#   'position': {'lat': 37.5405252, 'lon': -122.2552669},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12292969',
#   'id': '31827017',
#   'node_type': 'node',
#   'position': {'lat': 37.7485248, 'lon': -122.3922872},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '14160668',
#   'id': '31827102',
#   'node_type': 'node',
#   'position': {'lat': 37.7684637, 'lon': -122.2780001},
#   'time': {'day': 5, 'hour': 8, 'minute': 11, 'month': 12, 'year': 2012},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '6'},
#  {'changeset': '12291161',
#   'id': '31827162',
#   'node_type': 'node',
#   'position': {'lat': 37.8551573, 'lon': -122.4310807},
#   'time': {'day': 18, 'hour': 17, 'minute': 51, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12290072',
#   'id': '31827346',
#   'node_type': 'node',
#   'position': {'lat': 37.7118062, 'lon': -122.2070861},
#   'time': {'day': 18, 'hour': 17, 'minute': 10, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12289485',
#   'id': '31827440',
#   'node_type': 'node',
#   'position': {'lat': 37.7857239, 'lon': -122.2467344},
#   'time': {'day': 18, 'hour': 16, 'minute': 48, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '14159906',
#   'id': '31827837',
#   'node_type': 'node',
#   'position': {'lat': 37.7536403, 'lon': -122.2505035},
#   'time': {'day': 5, 'hour': 5, 'minute': 17, 'month': 12, 'year': 2012},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '15865774',
#   'id': '31827991',
#   'node_type': 'node',
#   'position': {'lat': 37.8984756, 'lon': -122.3141943},
#   'source': 'PGS',
#   'time': {'day': 25, 'hour': 21, 'minute': 14, 'month': 4, 'year': 2013},
#   'uid': '153669',
#   'user': 'dchiles',
#   'version': '3'},
#  {'changeset': '12290912',
#   'id': '31828088',
#   'node_type': 'node',
#   'position': {'lat': 37.9211092, 'lon': -122.3874259},
#   'time': {'day': 18, 'hour': 17, 'minute': 39, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '29113053',
#   'id': '31828214',
#   'node_type': 'node',
#   'position': {'lat': 37.7600609, 'lon': -122.2182373},
#   'time': {'day': 26, 'hour': 14, 'minute': 19, 'month': 2, 'year': 2015},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '6'},
#  {'changeset': '12291161',
#   'id': '31828347',
#   'node_type': 'node',
#   'position': {'lat': 37.8091166, 'lon': -122.4199342},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '6'},
#  {'changeset': '12290799',
#   'id': '31828422',
#   'node_type': 'node',
#   'position': {'lat': 37.8373543, 'lon': -122.3126539},
#   'time': {'day': 18, 'hour': 17, 'minute': 36, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12289746',
#   'id': '31828499',
#   'node_type': 'node',
#   'position': {'lat': 37.5104084, 'lon': -122.111379},
#   'time': {'day': 18, 'hour': 16, 'minute': 59, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '7'},
#  {'changeset': '12290233',
#   'id': '31828580',
#   'node_type': 'node',
#   'position': {'lat': 37.5164443, 'lon': -122.2025497},
#   'time': {'day': 18, 'hour': 17, 'minute': 15, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291412',
#   'id': '31828781',
#   'node_type': 'node',
#   'position': {'lat': 37.8269458, 'lon': -122.4839889},
#   'time': {'day': 18, 'hour': 18, 'minute': 1, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31828881',
#   'node_type': 'node',
#   'position': {'lat': 37.8538619, 'lon': -122.4213106},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '3'},
#  {'changeset': '12289485',
#   'id': '31828950',
#   'node_type': 'node',
#   'position': {'lat': 37.7566316, 'lon': -122.216831},
#   'time': {'day': 18, 'hour': 16, 'minute': 48, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292969',
#   'id': '31829040',
#   'node_type': 'node',
#   'position': {'lat': 37.708405, 'lon': -122.3793225},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '34237700',
#   'id': '31829166',
#   'node_type': 'node',
#   'position': {'lat': 37.7803033, 'lon': -122.2432235},
#   'time': {'day': 25, 'hour': 3, 'minute': 42, 'month': 9, 'year': 2015},
#   'uid': '3260615',
#   'user': 'SFBay1234',
#   'version': '6'},
#  {'changeset': '12290799',
#   'id': '31829267',
#   'node_type': 'node',
#   'position': {'lat': 37.8136945, 'lon': -122.359316},
#   'time': {'day': 18, 'hour': 17, 'minute': 36, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '16507049',
#   'id': '31829340',
#   'node_type': 'node',
#   'position': {'lat': 37.8066709, 'lon': -122.4500591},
#   'time': {'day': 11, 'hour': 8, 'minute': 34, 'month': 6, 'year': 2013},
#   'uid': '93788',
#   'user': 'coleman',
#   'version': '7'},
#  {'changeset': '12290631',
#   'id': '31829479',
#   'node_type': 'node',
#   'position': {'lat': 37.7934511, 'lon': -122.2980653},
#   'time': {'day': 18, 'hour': 17, 'minute': 31, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12292969',
#   'id': '31829558',
#   'node_type': 'node',
#   'position': {'lat': 37.6772969, 'lon': -122.3823991},
#   'time': {'day': 18, 'hour': 18, 'minute': 38, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291412',
#   'id': '31829678',
#   'node_type': 'node',
#   'position': {'lat': 37.8323646, 'lon': -122.4778923},
#   'time': {'day': 18, 'hour': 18, 'minute': 1, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12290233',
#   'id': '31829806',
#   'node_type': 'node',
#   'position': {'lat': 37.5424376, 'lon': -122.2497222},
#   'time': {'day': 18, 'hour': 17, 'minute': 15, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '16612448',
#   'id': '31829914',
#   'node_type': 'node',
#   'position': {'lat': 37.8051857, 'lon': -122.3260282},
#   'time': {'day': 19, 'hour': 4, 'minute': 53, 'month': 6, 'year': 2013},
#   'uid': '190493',
#   'user': 'vonvonvon',
#   'version': '5'},
#  {'changeset': '12297372',
#   'id': '31830014',
#   'node_type': 'node',
#   'position': {'lat': 37.8190276, 'lon': -122.5294488},
#   'time': {'day': 18, 'hour': 20, 'minute': 32, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '9'},
#  {'changeset': '12291003',
#   'id': '31830105',
#   'node_type': 'node',
#   'position': {'lat': 37.9489773, 'lon': -122.487374},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12291887',
#   'id': '31830205',
#   'node_type': 'node',
#   'position': {'lat': 37.7371861, 'lon': -122.3749234},
#   'time': {'day': 18, 'hour': 18, 'minute': 16, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12292084',
#   'id': '31830286',
#   'node_type': 'node',
#   'position': {'lat': 37.548477, 'lon': -122.2852344},
#   'time': {'day': 18, 'hour': 18, 'minute': 20, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31830402',
#   'node_type': 'node',
#   'position': {'lat': 37.7934894, 'lon': -122.3916442},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '10'},
#  {'changeset': '12291003',
#   'id': '31830473',
#   'node_type': 'node',
#   'position': {'lat': 37.8965996, 'lon': -122.4994856},
#   'time': {'day': 18, 'hour': 17, 'minute': 43, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '12290510',
#   'id': '31830552',
#   'node_type': 'node',
#   'position': {'lat': 37.9051487, 'lon': -122.3695108},
#   'time': {'day': 18, 'hour': 17, 'minute': 26, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '5'},
#  {'changeset': '12291161',
#   'id': '31830632',
#   'node_type': 'node',
#   'position': {'lat': 37.8085464, 'lon': -122.4323498},
#   'time': {'day': 18, 'hour': 17, 'minute': 50, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '10'},
#  {'changeset': '12297016',
#   'id': '31830714',
#   'node_type': 'node',
#   'position': {'lat': 37.8943713, 'lon': -122.5002066},
#   'time': {'day': 18, 'hour': 20, 'minute': 24, 'month': 7, 'year': 2012},
#   'uid': '722137',
#   'user': 'OSMF Redaction Account',
#   'version': '4'},
#  {'changeset': '14617259',
#   'id': '31830815',
#   'node_type': 'node',
#   'position': {'lat': 37.5363535, 'lon': -122.0946313},
# ...
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '8300994',
#   'id': '53021961',
#   'node_type': 'node',
#   'position': {'lat': 37.7450446, 'lon': -122.1502054},
#   'time': {'day': 31, 'hour': 12, 'minute': 16, 'month': 5, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'changeset': '18894823',
#   'highway': 'turning_circle',
#   'id': '53021980',
#   'node_type': 'node',
#   'position': {'lat': 37.6675762, 'lon': -122.1363788},
#   'time': {'day': 14, 'hour': 14, 'minute': 40, 'month': 11, 'year': 2013},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '4'},
#  {'changeset': '19064439',
#   'id': '53022074',
#   'node_type': 'node',
#   'position': {'lat': 37.5316735, 'lon': -122.0467791},
#   'time': {'day': 22, 'hour': 23, 'minute': 28, 'month': 11, 'year': 2013},
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '5'},
#  {'changeset': '4095390',
#   'id': '53022109',
#   'node_type': 'node',
#   'position': {'lat': 37.7783939, 'lon': -122.1727647},
#   'time': {'day': 11, 'hour': 5, 'minute': 54, 'month': 3, 'year': 2010},
#   'uid': '22946',
#   'user': 'David Muir Sharnoff',
#   'version': '6'},
#  {'changeset': '2172708',
#   'id': '53022146',
#   'node_type': 'node',
#   'position': {'lat': 37.5300269, 'lon': -122.0184575},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'changeset': '3499473',
#   'id': '53022185',
#   'node_type': 'node',
#   'position': {'lat': 37.5782134, 'lon': -122.0583309},
#   'time': {'day': 31, 'hour': 10, 'minute': 58, 'month': 12, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53022214',
#   'node_type': 'node',
#   'position': {'lat': 37.6263622, 'lon': -122.0579101},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'changeset': '4560702',
#   'id': '53022234',
#   'node_type': 'node',
#   'position': {'lat': 37.7723405, 'lon': -122.2750274},
#   'time': {'day': 29, 'hour': 20, 'minute': 9, 'month': 4, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '9034092',
#   'highway': 'turning_circle',
#   'id': '53022264',
#   'node_type': 'node',
#   'position': {'lat': 37.6918122, 'lon': -122.0840381},
#   'time': {'day': 16, 'hour': 7, 'minute': 45, 'month': 8, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '15114215',
#   'highway': 'turning_circle',
#   'id': '53022298',
#   'node_type': 'node',
#   'position': {'lat': 37.6350939, 'lon': -122.068831},
#   'time': {'day': 21, 'hour': 16, 'minute': 43, 'month': 2, 'year': 2013},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '5'},
#  {'changeset': '9034092',
#   'highway': 'turning_circle',
#   'id': '53022326',
#   'node_type': 'node',
#   'position': {'lat': 37.6924186, 'lon': -122.0837259},
#   'time': {'day': 16, 'hour': 7, 'minute': 45, 'month': 8, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'changeset': '6459153',
#   'highway': 'turning_circle',
#   'id': '53022340',
#   'node_type': 'node',
#   'position': {'lat': 37.5719371, 'lon': -122.0574799},
#   'time': {'day': 26, 'hour': 3, 'minute': 0, 'month': 11, 'year': 2010},
#   'uid': '162110',
#   'user': 'tahongawaka',
#   'version': '5'},
#  {'changeset': '6397206',
#   'highway': 'turning_circle',
#   'id': '53022417',
#   'node_type': 'node',
#   'position': {'lat': 37.605212, 'lon': -122.0698825},
#   'time': {'day': 18, 'hour': 0, 'minute': 50, 'month': 11, 'year': 2010},
#   'uid': '162110',
#   'user': 'tahongawaka',
#   'version': '5'},
#  {'changeset': '2172708',
#   'id': '53022529',
#   'node_type': 'node',
#   'position': {'lat': 37.6321239, 'lon': -122.0784649},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '4580658',
#   'id': '53022602',
#   'node_type': 'node',
#   'position': {'lat': 37.6838679, 'lon': -122.0499418},
#   'time': {'day': 2, 'hour': 0, 'minute': 49, 'month': 5, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'changeset': '18943005',
#   'id': '53022665',
#   'node_type': 'node',
#   'position': {'lat': 37.6516163, 'lon': -122.107872},
#   'time': {'day': 16, 'hour': 21, 'minute': 28, 'month': 11, 'year': 2013},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'changeset': '27430002',
#   'id': '53022695',
#   'node_type': 'node',
#   'position': {'lat': 37.8215868, 'lon': -122.2506063},
#   'time': {'day': 12, 'hour': 20, 'minute': 42, 'month': 12, 'year': 2014},
#   'uid': '153669',
#   'user': 'dchiles',
#   'version': '13'},
#  {'changeset': '4309199',
#   'id': '53022715',
#   'node_type': 'node',
#   'position': {'lat': 37.8337538, 'lon': -122.2731504},
#   'time': {'day': 3, 'hour': 0, 'minute': 16, 'month': 4, 'year': 2010},
#   'uid': '22946',
#   'user': 'David Muir Sharnoff',
#   'version': '8'},
#  {'changeset': '25780321',
#   'id': '53022778',
#   'node_type': 'node',
#   'position': {'lat': 37.6893578, 'lon': -122.1429564},
#   'time': {'day': 1, 'hour': 0, 'minute': 37, 'month': 10, 'year': 2014},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'changeset': '3405308',
#   'id': '53022803',
#   'node_type': 'node',
#   'position': {'lat': 37.6711985, 'lon': -122.1197751},
#   'time': {'day': 19, 'hour': 8, 'minute': 58, 'month': 12, 'year': 2009},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'changeset': '7781778',
#   'id': '53022827',
#   'node_type': 'node',
#   'position': {'lat': 37.798966, 'lon': -122.2474778},
#   'time': {'day': 6, 'hour': 6, 'minute': 59, 'month': 4, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'changeset': '2172708',
#   'id': '53022859',
#   'node_type': 'node',
#   'position': {'lat': 37.7030309, 'lon': -122.1359823},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '2498408',
#   'id': '53022884',
#   'node_type': 'node',
#   'position': {'lat': 37.7028092, 'lon': -122.1051235},
#   'time': {'day': 16, 'hour': 5, 'minute': 13, 'month': 9, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '7790247',
#   'id': '53022909',
#   'node_type': 'node',
#   'position': {'lat': 37.7867644, 'lon': -122.2950314},
#   'time': {'day': 6, 'hour': 23, 'minute': 33, 'month': 4, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '2172708',
#   'id': '53023014',
#   'node_type': 'node',
#   'position': {'lat': 37.6823593, 'lon': -122.1017949},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '2498408',
#   'id': '53023142',
#   'node_type': 'node',
#   'position': {'lat': 37.6670196, 'lon': -122.0496006},
#   'time': {'day': 16, 'hour': 5, 'minute': 13, 'month': 9, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '4570714',
#   'id': '53023166',
#   'node_type': 'node',
#   'position': {'lat': 37.7586511, 'lon': -122.2342136},
#   'time': {'day': 30, 'hour': 23, 'minute': 3, 'month': 4, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'changeset': '4929008',
#   'id': '53023212',
#   'node_type': 'node',
#   'position': {'lat': 37.5687707, 'lon': -122.068306},
#   'time': {'day': 7, 'hour': 15, 'minute': 34, 'month': 6, 'year': 2010},
#   'uid': '65950',
#   'user': 'davetoo',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53023279',
#   'node_type': 'node',
#   'position': {'lat': 37.8408681, 'lon': -122.2466529},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'changeset': '36709277',
#   'id': '53023323',
#   'node_type': 'node',
#   'position': {'lat': 37.6942533, 'lon': -122.1327088},
#   'time': {'day': 20, 'hour': 20, 'minute': 48, 'month': 1, 'year': 2016},
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53023359',
#   'node_type': 'node',
#   'position': {'lat': 37.5827588, 'lon': -122.0313396},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '3159438',
#   'id': '53023391',
#   'node_type': 'node',
#   'position': {'lat': 37.6389452, 'lon': -122.0812395},
#   'time': {'day': 19, 'hour': 12, 'minute': 27, 'month': 11, 'year': 2009},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'changeset': '2172708',
#   'id': '53023498',
#   'node_type': 'node',
#   'position': {'lat': 37.699061, 'lon': -122.177849},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'changeset': '4309928',
#   'id': '53023517',
#   'node_type': 'node',
#   'position': {'lat': 37.8198379, 'lon': -122.2317839},
#   'time': {'day': 3, 'hour': 6, 'minute': 16, 'month': 4, 'year': 2010},
#   'uid': '22946',
#   'user': 'David Muir Sharnoff',
#   'version': '5'},
#  {'changeset': '10926573',
#   'id': '53023555',
#   'node_type': 'node',
#   'position': {'lat': 37.5730229, 'lon': -122.0140612},
#   'time': {'day': 9, 'hour': 22, 'minute': 37, 'month': 3, 'year': 2012},
#   'uid': '482916',
#   'user': 'bill42',
#   'version': '4'},
#  {'changeset': '10952102',
#   'id': '53023704',
#   'node_type': 'node',
#   'position': {'lat': 37.8457015, 'lon': -122.2489526},
#   'time': {'day': 12, 'hour': 8, 'minute': 37, 'month': 3, 'year': 2012},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'changeset': '3941299',
#   'id': '53023767',
#   'node_type': 'node',
#   'position': {'lat': 37.7515917, 'lon': -122.1942483},
#   'time': {'day': 22, 'hour': 7, 'minute': 46, 'month': 2, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'changeset': '10952102',
#   'id': '53023867',
#   'node_type': 'node',
#   'position': {'lat': 37.8422905, 'lon': -122.2584168},
#   'time': {'day': 12, 'hour': 8, 'minute': 37, 'month': 3, 'year': 2012},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '33131509',
#   'id': '53024042',
#   'node_type': 'node',
#   'position': {'lat': 37.6658841, 'lon': -122.082165},
#   'time': {'day': 5, 'hour': 15, 'minute': 20, 'month': 8, 'year': 2015},
#   'uid': '567792',
#   'user': 'Natfoot',
#   'version': '9'},
#  {'changeset': '10982648',
#   'id': '53024162',
#   'node_type': 'node',
#   'position': {'lat': 37.8807992, 'lon': -122.2897466},
#   'time': {'day': 14, 'hour': 21, 'minute': 16, 'month': 3, 'year': 2012},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '3940397',
#   'id': '53024207',
#   'node_type': 'node',
#   'position': {'lat': 37.7873776, 'lon': -122.2459078},
#   'time': {'day': 22, 'hour': 1, 'minute': 15, 'month': 2, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'changeset': '2172708',
#   'id': '53024299',
#   'node_type': 'node',
#   'position': {'lat': 37.6054295, 'lon': -122.0765086},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '5275187',
#   'id': '53024316',
#   'node_type': 'node',
#   'position': {'lat': 37.7130254, 'lon': -122.133944},
#   'time': {'day': 20, 'hour': 23, 'minute': 49, 'month': 7, 'year': 2010},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '4'},
#  {'changeset': '2498408',
#   'id': '53024326',
#   'node_type': 'node',
#   'position': {'lat': 37.5770822, 'lon': -122.0435373},
#   'time': {'day': 16, 'hour': 5, 'minute': 13, 'month': 9, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'changeset': '2498408',
#   'id': '53024336',
#   'node_type': 'node',
#   'position': {'lat': 37.5416763, 'lon': -122.027492},
#   'time': {'day': 16, 'hour': 5, 'minute': 13, 'month': 9, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'changeset': '7818691',
#   'id': '53024364',
#   'node_type': 'node',
#   'position': {'lat': 37.785853, 'lon': -122.2901753},
#   'time': {'day': 10, 'hour': 0, 'minute': 52, 'month': 4, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'changeset': '4318455',
#   'id': '53024389',
#   'node_type': 'node',
#   'position': {'lat': 37.7319072, 'lon': -122.2336196},
#   'time': {'day': 4, 'hour': 0, 'minute': 21, 'month': 4, 'year': 2010},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53024420',
#   'node_type': 'node',
#   'position': {'lat': 37.6740689, 'lon': -122.0343433},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '5316607',
#   'id': '53024530',
#   'node_type': 'node',
#   'position': {'lat': 37.6718302, 'lon': -122.0625914},
#   'time': {'day': 25, 'hour': 20, 'minute': 56, 'month': 7, 'year': 2010},
#   'uid': '65950',
#   'user': 'davetoo',
#   'version': '7'},
#  {'changeset': '19259705',
#   'id': '53024548',
#   'node_type': 'node',
#   'position': {'lat': 37.6692731, 'lon': -122.0465238},
#   'time': {'day': 3, 'hour': 20, 'minute': 18, 'month': 12, 'year': 2013},
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '7'},
#  {'changeset': '18943005',
#   'id': '53024575',
#   'node_type': 'node',
#   'position': {'lat': 37.6589808, 'lon': -122.1106348},
#   'time': {'day': 16, 'hour': 21, 'minute': 28, 'month': 11, 'year': 2013},
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53024623',
#   'node_type': 'node',
#   'position': {'lat': 37.7011386, 'lon': -122.0636672},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'changeset': '41461112',
#   'id': '53024693',
#   'node_type': 'node',
#   'position': {'lat': 37.7690556, 'lon': -122.1939395},
#   'time': {'day': 15, 'hour': 6, 'minute': 33, 'month': 8, 'year': 2016},
#   'uid': '933797',
#   'user': 'oba510',
#   'version': '7'},
#  {'changeset': '2172708',
#   'id': '53024784',
#   'node_type': 'node',
#   'position': {'lat': 37.6045257, 'lon': -122.0733867},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'changeset': '2172708',
#   'id': '53024807',
#   'node_type': 'node',
#   'position': {'lat': 37.6027101, 'lon': -122.0774122},
#   'time': {'day': 17, 'hour': 3, 'minute': 0, 'month': 8, 'year': 2009},
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'changeset': '19241080',
#   'id': '53024846',
#   'node_type': 'node',
#   'position': {'lat': 37.6768121, 'lon': -122.0576503},
#   'time': {'day': 2, 'hour': 20, 'minute': 58, 'month': 12, 'year': 2013},
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '4'},
#  {'changeset': '7634218',
#   'id': '53024867',
#   'node_type': 'node',
#   'position': {'lat': 37.8396272, 'lon': -122.2424619},
#   'time': {'day': 22, 'hour': 7, 'minute': 6, 'month': 3, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'changeset': '26355636',
#   'id': '53024888',
#   'node_type': 'node',
#   'position': {'lat': 37.8403276, 'lon': -122.2184436},
#   'time': {'day': 27, 'hour': 4, 'minute': 49, 'month': 10, 'year': 2014},
#   'uid': '91499',
#   'user': 'paulmach',
#   'version': '7'},
#  {'changeset': '7634218',
#   'id': '53024909',
#   'node_type': 'node',
#   'position': {'lat': 37.8410653, 'lon': -122.2366956},
#   'time': {'day': 22, 'hour': 7, 'minute': 6, 'month': 3, 'year': 2011},
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'changeset': '6346279',
#   'id': '53024932',
#   'node_type': 'node',
#   'position': {'lat': 37.8409304, 'lon': -122.2152464},
#   'time': {'day': 11, 'hour': 20, 'minute': 10, 'month': 11, 'year': 2010},
#   'uid': '22946',
#   'user': 'David Muir Sharnoff',
#   'version': '5'},
#  ...]

# %%
post_style = re.compile(r'.*:.*')
key_set = set()
for item in dic_sample:
    for key, value in item.items():
        if post_style.match(key) and key not in key_set:
            key_set.add(key)

# %%
key_set
# Out:
# {'FG:COND_INDEX',
#  'FG:GPS_DATE',
#  'FG:ORG_CODE',
#  'FG:RTE',
#  'FG:area',
#  'FG:lane_miles',
#  'FG:perimeter',
#  'FG:photo',
#  'FG:route',
#  'FG:rte_description',
#  'FG:station',
#  'FG:visitors',
#  'Tiger:HYDROID',
#  'Tiger:MTFCC',
#  'abandoned:place',
#  'access:bicycle',
#  'access:conditional',
#  'access:emergency',
#  'access:foot',
#  'addr.source:housenumber',
#  'addr:',
#  'addr:city',
#  'addr:country',
#  'addr:county',
#  'addr:floor',
#  'addr:full',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:paloaltoca_id',
#  'addr:place',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:street:source',
#  'addr:unit',
#  'area:highway',
#  'atm:network',
#  'attribution:wikipedia',
#  'bicycle:lanes:backward',
#  'bicycle:lanes:forward',
#  'blind:description:en',
#  'boundary:type',
#  'bridge:alt_name',
#  'bridge:name',
#  'bridge:old_name',
#  'bridge:structure',
#  'building:colour',
#  'building:levels',
#  'building:material',
#  'building:min_level',
#  'building:part',
#  'bus:lanes:backward',
#  'caltrans:district',
#  'caltrans:dynsegpm',
#  'caltrans:pctuse',
#  'caltrans:type',
#  'camp_site:fire',
#  'camp_site:table',
#  'camp_site:type',
#  'capacity:disabled',
#  'census:population',
#  'change:backward',
#  'change:forward',
#  'change:lanes',
#  'class:bicycle',
#  'contact:email',
#  'contact:fax',
#  'contact:myspace',
#  'contact:phone',
#  'contact:website',
#  'crossing:bell',
#  'crossing:light',
#  'csp:globalid',
#  'csp:unitcode',
#  'currency:USD',
#  'cycleway:left',
#  'cycleway:right',
#  'delivery:partner',
#  'description:en',
#  'destination:backward',
#  'destination:forward',
#  'destination:lanes',
#  'destination:ref',
#  'destination:ref:backward',
#  'destination:ref:forward',
#  'destination:ref:to',
#  'destination:street',
#  'diet:vegan',
#  'diet:vegetarian',
#  'disused:amenity',
#  'disused:highway',
#  'disused:name',
#  'disused:office',
#  'disused:religion',
#  'disused:shop',
#  'drinking_water:bottle',
#  'drinking_water:dog',
#  'emergency:notes',
#  'fire_hydrant:position',
#  'fire_hydrant:type',
#  'fixme:name',
#  'fuel:cng',
#  'generator:method',
#  'generator:output:electricity',
#  'generator:place',
#  'generator:source',
#  'generator:type',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:edited',
#  'gnis:feature_id',
#  'gnis:feature_type',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf:course',
#  'golf:par',
#  'gosm:sig:8CBDE645',
#  'healthcare:speciality',
#  'hgv:national_network',
#  'hgv:state_network',
#  'historic:amenity',
#  'historic:denomination',
#  'historic:name',
#  'historic:religion',
#  'historical:name',
#  'hov:lanes',
#  'internet_access:fee',
#  'is_in:continent',
#  'is_in:country',
#  'is_in:country_code',
#  'is_in:county',
#  'is_in:iso_3166_2',
#  'is_in:state',
#  'is_in:state_code',
#  'lanes:backward',
#  'lanes:both_ways',
#  'lanes:bus',
#  'lanes:extra',
#  'lanes:forward',
#  'language:en',
#  'lastcheck:date',
#  'massgis:cat',
#  'maxspeed:advisory',
#  'maxspeed:advisory:forward',
#  'maxspeed:hgv',
#  'maxspeed:trailer',
#  'maxspeed:trailers',
#  'minweight:hgv',
#  'monitoring:water_level',
#  'mrosd:preserve',
#  'mrosd:version',
#  'mtb:scale',
#  'name:ar',
#  'name:de',
#  'name:en',
#  'name:es',
#  'name:etymology:wikidata',
#  'name:fa',
#  'name:he',
#  'name:hu',
#  'name:ja',
#  'name:ko',
#  'name:pa',
#  'name:ru',
#  'name:zh',
#  'nextbus:agency',
#  'nextbus:dir',
#  'nextbus:route',
#  'nextbus:stopid',
#  'nhd:reach_code',
#  'noaa:geohash',
#  'noaa:lnam',
#  'noaa:taghash',
#  'note:address',
#  'note:highway',
#  'note:lanes',
#  'note:lcn',
#  'nps:length',
#  'nps:pets',
#  'nps:trail',
#  'odbl:note',
#  'old:name',
#  'oneway:bicycle',
#  'operator:type',
#  'operator:wikipedia',
#  'paloalto_ca:id',
#  'park:type',
#  'parking:condition:both',
#  'parking:condition:both:maxstay',
#  'parking:condition:both:residents',
#  'parking:condition:both:time_interval',
#  'parking:condition:left',
#  'parking:condition:left:2',
#  'parking:condition:left:2:reason',
#  'parking:condition:left:2:time_interval',
#  'parking:condition:left:maxstay',
#  'parking:condition:left:residents',
#  'parking:condition:left:time_interval',
#  'parking:condition:right',
#  'parking:condition:right:2',
#  'parking:condition:right:2:reason',
#  'parking:condition:right:2:time_interval',
#  'parking:condition:right:maxstay',
#  'parking:condition:right:residents',
#  'parking:condition:right:time_interval',
#  'parking:lane:both',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:restricted',
#  'payment:american_express',
#  'payment:bitcoin',
#  'payment:cash',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:diners_club',
#  'payment:discover_card',
#  'payment:dogecoin',
#  'payment:litecoin',
#  'payment:mastercard',
#  'payment:peercoin',
#  'payment:vertcoin',
#  'payment:visa',
#  'placement:backward',
#  'public_transport:version',
#  'railway:traffic_mode',
#  'recycling:clothes',
#  'redwood_city_ca:addr_id',
#  'redwood_city_ca:bld_gid',
#  'redwood_city_ca:bldg_id',
#  'ref:blklot',
#  'ref:left',
#  'ref:nrhp',
#  'ref:right',
#  'restriction:conditional',
#  'roof:colour',
#  'roof:height',
#  'roof:shape',
#  'roof:slope:direction',
#  'rwc_ca:address_id',
#  'rwc_ca:buildingid',
#  'rwc_ca:id',
#  'scvwd:FACILITY',
#  'scvwd:NAME',
#  'scvwd:OBJECTID',
#  'scvwd:ROUTEID',
#  'scvwd:SHAPE_Area',
#  'seamark:beacon_lateral:category',
#  'seamark:beacon_lateral:colour',
#  'seamark:beacon_lateral:reflectivity',
#  'seamark:beacon_lateral:shape',
#  'seamark:beacon_safe_water:shape',
#  'seamark:beacon_special_purpose:category',
#  'seamark:beacon_special_purpose:colour',
#  'seamark:beacon_special_purpose:shape',
#  'seamark:buoy_lateral:category',
#  'seamark:buoy_lateral:colour',
#  'seamark:buoy_lateral:shape',
#  'seamark:buoy_lateral:system',
#  'seamark:buoy_special_purpose:colour',
#  'seamark:buoy_special_purpose:shape',
#  'seamark:daymark:colour',
#  'seamark:daymark:colour_pattern',
#  'seamark:daymark:construction',
#  'seamark:daymark:shape',
#  'seamark:fog_signal:category',
#  'seamark:fog_signal:generation',
#  'seamark:fog_signal:group',
#  'seamark:fog_signal:period',
#  'seamark:fog_signal:sequence',
#  'seamark:information',
#  'seamark:light:character',
#  'seamark:light:colour',
#  'seamark:light:exhibition',
#  'seamark:light:height',
#  'seamark:light:period',
#  'seamark:light:range',
#  'seamark:light:reference',
#  'seamark:light:sequence',
#  'seamark:mooring:category',
#  'seamark:mooring:water_level',
#  'seamark:name',
#  'seamark:radar_reflector',
#  'seamark:rock:depth',
#  'seamark:rock:exposition',
#  'seamark:rock:quality',
#  'seamark:rock:water_level',
#  'seamark:small_craft_facility:category',
#  'seamark:status',
#  'seamark:type',
#  'service:bicycle:cleaning',
#  'service:bicycle:diy',
#  'service:bicycle:pump',
#  'service:bicycle:rental',
#  'service:bicycle:repair',
#  'service:bicycle:retail',
#  'service:bicycle:second_hand',
#  'sfgov.org:OBJECTID',
#  'sfgov.org:OFFICE_TYP',
#  'sfgov:OBJNAME',
#  'ship:type',
#  'slipway:type',
#  'social_facility:for',
#  'socket:chademo',
#  'socket:type1',
#  'socket:type1_combo',
#  'source:amenity',
#  'source:destination',
#  'source:hgv:national_network',
#  'source:hgv:state_network',
#  'source:maxspeed',
#  'source:maxspeed:advisory:forward',
#  'source:maxspeed:backward',
#  'source:name',
#  'source:pkey',
#  'source:population',
#  'source:website',
#  'species:en',
#  'speech_output:en',
#  'surveillance:type',
#  'survey:date',
#  'theatre:genre',
#  'tiger:ALAND',
#  'tiger:AREAID',
#  'tiger:AWATER',
#  'tiger:CLASSFP',
#  'tiger:COUNTYFP',
#  'tiger:CPI',
#  'tiger:FUNCSTAT',
#  'tiger:LINEARID',
#  'tiger:LSAD',
#  'tiger:MTFCC',
#  'tiger:NAME',
#  'tiger:NAMELSAD',
#  'tiger:PCICBSA',
#  'tiger:PCINECTA',
#  'tiger:PLACEFP',
#  'tiger:PLACENS',
#  'tiger:PLCIDFP',
#  'tiger:RTTYP',
#  'tiger:STATEFP',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_suffix',
#  'tiger:name_direction_suffix_1',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:name_type_2',
#  'tiger:name_type_3',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_left_2',
#  'tiger:zip_left_3',
#  'tiger:zip_left_4',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'tiger:zip_right_2',
#  'tiger:zip_right_3',
#  'toilets:disposal',
#  'toilets:position',
#  'toilets:wheelchair',
#  'tower:type',
#  'traffic_signals:direction',
#  'traffic_signals:sound',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:both_ways',
#  'turn:lanes:forward',
#  'verified:name',
#  'wetap:flow',
#  'wetap:photo',
#  'wetap:quality',
#  'wetap:status',
#  'wetap:statusnote',
#  'wetap:temperature',
#  'wheelchair:description'}

# %%
# change key:sub_key pairs into key: {subkey1:..., subkey2:...,...}

re_style = re.compile(r'.+:.+')

for item in dic_sample:
    
    key_set = set()
    
    for item_key in item.keys():
        if re_style.match(item_key):
            item_subkeys = item_key.split(':')
            if len(item_subkeys) >= 2:
                if item_subkeys[0] not in key_set:
                    key_set.add(item_subkeys[0])
                    item[item_subkeys[0]] = {}
            
                item[item_subkeys[0]][item_subkeys[1]] = item.pop(item_key)

# %% [markdown]
# Some keys, for example: {'addr.source', 'sfgov.org'} is not suitable to be used in MongoDB so I replace them.

# %%
post_style = re.compile(r'.+\..+')
for item in dic_sample:
    for key, value in item.items():
        if key == 'addr.source':
            item['addr_source'] = item.pop('addr.source')
        elif key == 'sfgov.org':
            item['sfgov'] = item.pop('sfgov.org')

# %% [markdown]
# Now dic_sample saved our data in a pretty good format, so I can store it into a JSON file.

# %%
import json
with open('data_example.json', 'w') as fp:
    json.dump(dic_sample, fp)

# %% [markdown]
# Now start my MongoDB, go to terminal! Input:
#
# *$ sudo mongod*
#
# Then
#
# *$ *

# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost:27017')
db = client.openstreetmap

for item in dic_sample:
    db.openstreetmap.insert_one(item)

# %%
# db.openstreetmap.drop()

# %%
def aggregate(db, pipeline):
    return [doc for doc in db.openstreetmap.aggregate(pipeline)]

# %%
def make_pipeline():
    pipeline = [{"$group": {"_id": "$user",
                                        "count": {"$sum": 1}}},
                            {"$sort": {"count": -1}},
                            {"$limit": 10}
]
    return pipeline

# %%
# top 10 most contribution users
import pprint
pipeline = make_pipeline()
result = aggregate(db, pipeline)
pprint.pprint(result)
# Out:
# [{u'_id': u'ediyes', u'count': 91956},
#  {u'_id': u'Luis36995', u'count': 71021},
#  {u'_id': u'Rub21', u'count': 39577},
#  {u'_id': u'RichRico', u'count': 22502},
#  {u'_id': u'calfarome', u'count': 18564},
#  {u'_id': u'oldtopos', u'count': 16749},
#  {u'_id': u'KindredCoda', u'count': 15117},
#  {u'_id': u'karitotp', u'count': 13605},
#  {u'_id': u'samely', u'count': 12647},
#  {u'_id': u'abel801', u'count': 10851}]

# %%
# most contribution hour
def make_pipeline():
    pipeline = [{"$group": {"_id": "$time.hour",
                                        "count": {"$sum": 1}}},
                            {"$sort": {"count": -1}},
                            {"$limit": 24}
]
    return pipeline

pipeline = make_pipeline()
result = aggregate(db, pipeline)
result_dic = {}
for item in result:
    result_dic[item['_id']] = item['count']

# %%
import matplotlib.pyplot as plt


plt.bar(range(len(result_dic)), result_dic.values(), align='center')
plt.show()

# %%
# most contribution month
def make_pipeline():
    pipeline = [{"$group": {"_id": "$time.month",
                                        "count": {"$sum": 1}}},
                            {"$sort": {"count": -1}},
                            {"$limit": 24}
]
    return pipeline

pipeline = make_pipeline()
result = aggregate(db, pipeline)
result_dic = {}
for item in result:
    result_dic[item['_id']] = item['count']

plt.bar(range(len(result_dic)), result_dic.values(), align='center')
plt.show()
